# %%
import pandas as pd

# %%
Jan19 = pd.read_csv("./Resources/JC-201901-citibike-tripdata.csv")
Feb19 = pd.read_csv("./Resources/JC-201902-citibike-tripdata.csv")
Mar19 = pd.read_csv("./Resources/JC-201903-citibike-tripdata.csv")
Apr19 = pd.read_csv("./Resources/JC-201904-citibike-tripdata.csv")
May19 = pd.read_csv("./Resources/JC-201905-citibike-tripdata.csv")
Jun19 = pd.read_csv("./Resources/JC-201906-citibike-tripdata.csv")
Jul19 = pd.read_csv("./Resources/JC-201907-citibike-tripdata.csv")
Aug19 = pd.read_csv("./Resources/JC-201908-citibike-tripdata.csv")
Sep19 = pd.read_csv("./Resources/JC-201909-citibike-tripdata.csv")
Oct19 = pd.read_csv("./Resources/JC-201910-citibike-tripdata.csv")
Nov19 = pd.read_csv("./Resources/JC-201911-citibike-tripdata.csv")
Dec19 = pd.read_csv("./Resources/JC-201912-citibike-tripdata.csv")
Jan20 = pd.read_csv("./Resources/JC-202001-citibike-tripdata.csv")
Feb20 = pd.read_csv("./Resources/JC-202002-citibike-tripdata.csv")
Mar20 = pd.read_csv("./Resources/JC-202003-citibike-tripdata.csv")
Apr20 = pd.read_csv("./Resources/JC-202004-citibike-tripdata.csv")
May20 = pd.read_csv("./Resources/JC-202005-citibike-tripdata.csv")
Jun20 = pd.read_csv("./Resources/JC-202006-citibike-tripdata.csv")
Jul20 = pd.read_csv("./Resources/JC-202007-citibike-tripdata.csv")

# %%
Jan19.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
data = Jan19.append(Feb19)
data = data.append(Mar19)
data = data.append(Apr19)
data = data.append(May19)
data = data.append(Jun19)
data = data.append(Jul19)
data = data.append(Aug19)
data = data.append(Sep19)
data = data.append(Oct19)
data = data.append(Nov19)
data = data.append(Dec19)
data = data.append(Jan20)
data = data.append(Feb20)
data = data.append(Mar20)
data = data.append(Apr20)
data = data.append(May20)
data = data.append(Jun20)
data = data.append(Jul20)
data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 38675          1003  2020-07-31 23:51:37.3790  2020-08-01 00:08:20.6900
# 38676           165  2020-07-31 23:56:33.6770  2020-07-31 23:59:18.8610
# 38677           382  2020-07-31 23:56:55.9860  2020-08-01 00:03:18.8390
# 38678           674  2020-07-31 23:57:58.0150  2020-08-01 00:09:12.0420
# 38679          1007  2020-07-31 23:58:06.3070  2020-08-01 00:14:53.3340
#
#        start station id          start station name  start station latitude  \
# ...

# %%
data.to_csv("Output/data.csv")
